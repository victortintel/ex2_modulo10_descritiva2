# %% [markdown]
# # Módulo 10 tarefa 2
#
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Com o que você viu em aula, faça uma análise das variáveis qualitativas (posse de imóvel e posse de veículo) para verificar se são boas preditoras de *renda*. Alguma delas parece discriminar *renda* de forma estatisticamente significante?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("previsao_de_renda.csv")
df
# Out:
#        Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0               0  2015-01-01   8682    F             False             True
# 1               1  2015-01-01  12830    M              True             True
# 2               2  2015-01-01   2885    M              True             True
# 3               3  2015-01-01  16168    F              True            False
# 4               4  2015-01-01  12438    M             False            False
# ...           ...         ...    ...  ...               ...              ...
# 14995       14995  2016-03-01   3678    M              True             True
# 14996       14996  2016-03-01   3405    M              True             True
# 14997       14997  2016-03-01   7944    F              True             True
# 14998       14998  2016-03-01  16019    F             False             True
# 14999       14999  2016-03-01  12895    F              True             True
#
# ...

# %%
ax = sns.pointplot(x="posse_de_imovel", y="renda", data=df, dodge=True, errorbar=('ci', 90))

# %%
ax = sns.pointplot(x="posse_de_veiculo", y="renda", data=df, dodge=True, errorbar=('ci', 90))

# %%
print("O gráfico de posse de veículo conseguimos ter uma boa analise que claramente as pessoas com veículo apresentam uma renda maior. Porém, na questão de imóvel, essa diferença é muito pequena, então eu não consideraria um bom ponto para ser analisado. ")
# Out:
# O gráfico de posse de veículo conseguimos ter uma boa analise que claramente as pessoas com veículo apresentam uma renda maior. Porém, na questão de imóvel, essa diferença é muito pequena, então eu não consideraria um bom ponto para ser analisado.
